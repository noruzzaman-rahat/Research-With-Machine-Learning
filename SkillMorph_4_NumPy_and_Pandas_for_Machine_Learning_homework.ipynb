# %% [markdown]
# <a href="https://colab.research.google.com/github/noruzzaman-rahat/Research-With-Machine-Learning/blob/main/SkillMorph_4_NumPy_and_Pandas_for_Machine_Learning_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 4. Practice
#
# ### Exercise 1 — NumPy
# Given `arr = np.random.randint(1, 101, 20)`:
# 1. Print its sum, min, and max.
# 2. Create a second array of the same size and multiply them element-wise.

# %%
import numpy as np

arr = np.random.randint(1, 101, 20)

print("Array:", arr)

# Sum, Min, Max
print("Sum:", np.sum(arr))
print("Min:", np.min(arr))
print("Max:", np.max(arr))
# Out:
# Array: [ 1 35 52 84  2  8 41 21 48 16 58 21 52 16 28 13 82 97 42 11]
# Sum: 728
# Min: 1
# Max: 97

# %%
import numpy as np

arr1 = np.random.randint(1, 101, 20)
arr2 = np.random.randint(1, 101, 20)

print("Array 1:", arr1)
print("Array 2:", arr2)

result = arr1 * arr2

print("Result:", result)
# Out:
# Array 1: [93 63 72 42 24 82 24 89 67 82 11 33  3  4 52 67 20 62 18 26]
# Array 2: [58 77 14 37 17 15 51 42 69 65  8 25 61 49 23  9 90 88 50  2]
# Result: [5394 4851 1008 1554  408 1230 1224 3738 4623 5330   88  825  183  196
#  1196  603 1800 5456  900   52]

# %% [markdown]
# ### Exercise 2 — Pandas
# Get a recent unique dataset from Kaggle or another source and compute basic statistics using Pandas
#
# 1. Choose a dataset — Download a current dataset from Kaggle
# 2. Load the dataset into a Pandas DataFrame.
# 3. Explore and inspect the data with Pandas methods.
# 4. Compute and display basic statistical summaries, including:
# Descriptive statistics (describe)
# Missing value counts
# Data types
# Class balance (if applicable)
# Unique values and distributions

# %%
# Your solution here
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/skill morph/crypto_asset_snapshot.csv'


df = pd.read_csv(file_path)   # raw CSV has no header
print('Loaded:', df.shape)
# Out:
# Loaded: (8, 24)

# %%
df.head()
# Out:
#        coin_id symbol      name     price_usd  market_cap_usd  \
# 0      bitcoin    btc   Bitcoin  77488.000000   1551408842798
# 1     ethereum    eth  Ethereum   2320.820000    280099496059
# 2  binancecoin    bnb       BNB    632.730000     85283538168
# 3     usd-coin   usdc      USDC      0.999724     78207496853
# 4       solana    sol    Solana     85.610000     49260881705
#
#    market_cap_rank  volume_usd_24h  price_change_24h_pct  price_change_7d_pct  \
# 0                1     45509173816              -1.02506             4.245291
# 1                2     20850389369              -2.99789            -0.773757
# 2                5      1179587205              -1.45434             2.072612
# 3                6     16936167228              -0.00807            -0.006382
# 4                7      3792276475              -3.04873             0.370668
#
#    circulating_supply  ...              last_updated  twitter_followers  \
# 0        2.001961e+07  ...  2026-04-23T11:29:46.793Z                NaN
# 1        1.206893e+08  ...  2026-04-23T11:29:46.170Z                NaN
# 2        1.347865e+08  ...  2026-04-23T11:29:49.115Z                NaN
# 3        7.822226e+10  ...  2026-04-23T11:29:48.169Z                NaN
# 4        5.756128e+08  ...  2026-04-23T11:29:46.737Z                NaN
#
#    reddit_subscribers  reddit_active_users_48h telegram_channel_user_count  \
# 0                 0.0                      0.0                         NaN
# 1                 0.0                      0.0                         NaN
# 2                 0.0                      0.0                         NaN
# 3                 0.0                      0.0                         NaN
# 4                 NaN                      NaN                         NaN
#
#    github_stars  github_forks   source_price  \
# 0       73168.0       36426.0  CoinGecko API
# 1       44422.0       19618.0  CoinGecko API
# 2        4241.0        2042.0  CoinGecko API
# 3         737.0         533.0  CoinGecko API
# 4           NaN           NaN  CoinGecko API
#
#                         source_social                  retrieved_at_utc
# 0  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
# 1  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
# 2  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
# 3  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
# 4  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
#
# [5 rows x 24 columns]

# %%
df.tail()
# Out:
#     coin_id symbol      name  price_usd  market_cap_usd  market_cap_rank  \
# 3  usd-coin   usdc      USDC   0.999724     78207496853                6
# 4    solana    sol    Solana  85.610000     49260881705                7
# 5      tron    trx      TRON   0.328140     31100134713                8
# 6  dogecoin   doge  Dogecoin   0.095925     14765797689               10
# 7   cardano    ada   Cardano   0.246312      9104042504               15
#
#    volume_usd_24h  price_change_24h_pct  price_change_7d_pct  \
# 3     16936167228              -0.00807            -0.006382
# 4      3792276475              -3.04873             0.370668
# 5       630973735              -1.68722             0.437857
# 6      1419543611              -2.32104            -0.111150
# 7       379113808              -3.63174            -0.690511
#
#    circulating_supply  ...              last_updated  twitter_followers  \
# 3        7.822226e+10  ...  2026-04-23T11:29:48.169Z                NaN
# 4        5.756128e+08  ...  2026-04-23T11:29:46.737Z                NaN
# 5        9.478035e+10  ...  2026-04-23T11:29:44.550Z                NaN
# 6        1.539439e+11  ...  2026-04-23T11:29:46.928Z                NaN
# 7        3.696147e+10  ...  2026-04-23T11:29:49.121Z                NaN
#
#    reddit_subscribers  reddit_active_users_48h telegram_channel_user_count  \
# 3                 0.0                      0.0                         NaN
# 4                 NaN                      NaN                         NaN
# 5                 0.0                      0.0                     47234.0
# 6                 NaN                      NaN                         NaN
# 7                 0.0                      0.0                     15493.0
#
#    github_stars  github_forks   source_price  \
# 3         737.0         533.0  CoinGecko API
# 4           NaN           NaN  CoinGecko API
# 5        3530.0        1438.0  CoinGecko API
# 6           NaN           NaN  CoinGecko API
# 7        3757.0         643.0  CoinGecko API
#
#                         source_social                  retrieved_at_utc
# 3  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
# 4  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
# 5  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
# 6  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
# 7  CoinGecko community/developer data  2026-04-23T11:29:46.625822+00:00
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#           price_usd  market_cap_usd  market_cap_rank  volume_usd_24h  \
# count      8.000000    8.000000e+00         8.000000    8.000000e+00
# mean   10066.103763    2.624038e+11         6.750000    1.133715e+10
# std    27254.285292    5.280102e+11         4.464143    1.595860e+10
# min        0.095925    9.104043e+09         1.000000    3.791138e+08
# 25%        0.307683    2.701655e+10         4.250000    1.042434e+09
# 50%       43.304862    6.373419e+10         6.500000    2.605910e+09
# 75%     1054.752500    1.339875e+11         8.500000    1.791472e+10
# max    77488.000000    1.551409e+12        15.000000    4.550917e+10
#
#        price_change_24h_pct  price_change_7d_pct  circulating_supply  \
# count              8.000000             8.000000        8.000000e+00
# mean              -2.021761             0.693079        4.559489e+10
# std                1.205425             1.685754        5.798539e+10
# min               -3.631740            -0.773757        2.001961e+07
# 25%               -3.010600            -0.255990        1.312622e+08
# 50%               -2.004130             0.182143        1.876854e+10
# 75%               -1.347020             0.846546        8.236179e+10
# max               -0.008070             4.245291        1.539439e+11
#
#        total_supply    max_supply  all_time_high_usd  all_time_low_usd  \
# count  8.000000e+00  3.000000e+00           8.000000          8.000000
# mean   4.661442e+10  1.507367e+10       16586.830733          8.710299
# std    5.788402e+10  2.591712e+10       44274.483292         23.882008
# min    2.001961e+07  2.100000e+07           0.431288          0.000087
# 25%    1.312622e+08  1.105000e+08           0.965144          0.014891
# 50%    2.281246e+10  2.000000e+08         148.200000          0.236398
# 75%    8.241182e+10  2.260000e+10        2264.005000          0.595013
# max    1.539456e+11  4.500000e+10      126080.000000         67.810000
#
#        twitter_followers  reddit_subscribers  reddit_active_users_48h  \
# count                0.0                 6.0                      6.0
# mean                 NaN                 0.0                      0.0
# std                  NaN                 0.0                      0.0
# min                  NaN                 0.0                      0.0
# 25%                  NaN                 0.0                      0.0
# 50%                  NaN                 0.0                      0.0
# 75%                  NaN                 0.0                      0.0
# max                  NaN                 0.0                      0.0
#
#        telegram_channel_user_count  github_stars  github_forks
# count                     2.000000      6.000000      6.000000
# mean                  31363.500000  21642.500000  10116.666667
# std                   22444.276342  30204.597893  14863.195345
# min                   15493.000000    737.000000    533.000000
# 25%                   23428.250000   3586.750000    841.750000
# 50%                   31363.500000   3999.000000   1740.000000
# 75%                   39298.750000  34376.750000  15224.000000
# max                   47234.000000  73168.000000  36426.000000

# %%
# Missing values and class balance — two checks you should always do
print('Missing per column:\n', df.isnull().sum(), sep='')
# Out:
# Missing per column:
# coin_id                        0
# symbol                         0
# name                           0
# price_usd                      0
# market_cap_usd                 0
# market_cap_rank                0
# volume_usd_24h                 0
# price_change_24h_pct           0
# price_change_7d_pct            0
# circulating_supply             0
# total_supply                   0
# max_supply                     5
# all_time_high_usd              0
# all_time_low_usd               0
# last_updated                   0
# twitter_followers              8
# reddit_subscribers             2
# reddit_active_users_48h        2
# telegram_channel_user_count    6
# github_stars                   2
# github_forks                   2
# source_price                   0
# source_social                  0
# retrieved_at_utc               0
# dtype: int64
